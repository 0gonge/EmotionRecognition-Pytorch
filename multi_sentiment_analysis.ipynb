# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
import os
import pickle
import numpy as np
import argparse
from random import random

from torch import optim
from sklearn.metrics import f1_score

import torch
import torch.nn as nn
from torch.nn import functional as F

from sklearn.utils import shuffle

import numpy as np
import random

import torch
import torch.nn as nn
from torch.autograd import Function
from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence, pad_packed_sequence

# %%
def preprocess(au_mfcc_path):
    data = []
    labels = []
    with open(au_mfcc_path, 'rb') as f:
        au_mfcc = pickle.load(f)

    for key in au_mfcc:
        emotion = key.split('-')[2]
        emotion = int(emotion)-1
        labels.append(emotion)
        data.append(au_mfcc[key])

    data=np.array(data)
    labels = np.array(labels)
    labels = labels.reshape(labels.shape+(1,))

    data = np.hstack((data, labels))
    fdata = shuffle(data)

    data = fdata[:, :-1]
    labels = fdata[:, -1].astype(int)

    return data, labels

# %%
data_path =r'/content/drive/MyDrive/multimodal-fusion/au_mfcc.pkl'

data, labels=preprocess(data_path)

data.shape, labels.shape
#split data into train, validation, testset
# Out:
# ((1440, 294), (1440,))

# %%
new_labels= np.zeros((labels.shape[0], np.unique(labels.astype(int)).size))

for i in range(len(labels)):
    new_labels[i, labels[i]]=1

labels=new_labels

test_data=data[-181:-1]
test_labels=labels[-181:-1]
data=data[:-180]
labels=labels[:-180]

train_data=data[:1020]
train_labels=labels[:1020]

dev_data=data[1020:]
dev_labels=labels[1020:]

# %%
train_data.shape, dev_data.shape, test_data.shape
# Out:
# ((1020, 294), (240, 294), (180, 294))

# %%
torch.cuda.is_available()
# Out:
# True

# %%
class MMF_Model(nn.Module):
  def __init__(self):
    super(MMF_Model, self).__init__()
    #todo: declare au_rnn and mfcss_rnn
    rnn = nn.LSTM

    self.au_rnn1 = rnn(35, 16, bidirectional=True)
    self.au_rnn2 = rnn(2*16, 16, bidirectional=True)

    self.mfccs_rnn1 = rnn(259, 16, bidirectional = True)
    self.mfccs_rnn2 = rnn(2*16, 16, bidirectional= True)

    self.fc = nn.Linear(in_features= 128, out_features=8)

  def extract_aus(self, au, lengths):
    packed_sequence = pack_padded_sequence(au, lengths)
    packed_h1, (final_h1, _) = self.au_rnn1(packed_sequence)
    padded_h1, _ = pad_packed_sequence(packed_h1)
    packed_normed_h1 = pack_padded_sequence(padded_h1, lengths)
    _, (final_h2, _) = self.au_rnn2(packed_normed_h1)
    extracted_au = torch.cat((final_h1, final_h2), dim=2).permute(1,0,2).contiguous().view(batch_size,-1)

    return extracted_au

  def extract_mfccs(self, mfccs, lengths):
    packed_sequence = pack_padded_sequence(mfccs, lengths)
    packed_h1, (final_h1, _) = self.mfccs_rnn1(packed_sequence)  # Fixed here
    padded_h1, _ = pad_packed_sequence(packed_h1)
    packed_normed_h1 = pack_padded_sequence(padded_h1, lengths)
    _, (final_h2, _) = self.mfccs_rnn2(packed_normed_h1)
    extracted_mfccs = torch.cat((final_h1, final_h2), dim=2).permute(1, 0, 2).contiguous().view(mfccs.size(1), -1)

    return extracted_mfccs


  def forward(self, au, mfccs, lengths):
    extracted_au = self.extract_aus(au, lengths)
    extracted_mfccs = self.extract_mfccs(mfccs, lengths)

    fused_features = torch.cat((extracted_au, extracted_mfccs), dim=1)

    output = self.fc(fused_features) #60x8
    return output

# %%
def eval(data, labels, mode=None, to_print=False):
    assert(mode is not None)

    model.eval()

    y_true, y_pred = [], []
    eval_loss, eval_loss_diff = [], []

    if mode == "test":
        if to_print:
            model.load_state_dict(torch.load(
                f'/content/drive/MyDrive/multimodal-fusion/model.ckpt'))

    corr=0
    with torch.no_grad():
        for i in range(0, len(data), 60):
            model.zero_grad()
            # v, a, y, l = batch
            d=data[i:i+60]
            l=labels[i:i+60]
            d=np.expand_dims(d,axis=0)
            au=torch.from_numpy(d[:, :, :35]).float()
            mfccs=torch.from_numpy(d[:, :, 35:]).float()
            y=torch.from_numpy(l).float()

            lengths = torch.LongTensor([au.shape[0]]*au.size(1))

            au = au.cuda()
            mfccs = mfccs.cuda()
            y = y.cuda()

            output = model(au, mfccs, lengths)

            loss =  criterion(output, y)

            eval_loss.append(loss.item())
            preds=output.detach().cpu().numpy()
            y_trues=y.detach().cpu().numpy()

            for j in range(len(preds)):
                pred=np.argmax(preds[j])
                y_true=np.argmax(y_trues[j])
                if pred==y_true:
                    corr+=1

    eval_loss = np.mean(eval_loss)

    accuracy = corr/(1.0*len(labels))

    return eval_loss, accuracy

# %%
model = MMF_Model().cuda()
optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=1e-3)
criterion = nn.CrossEntropyLoss()
batch_size = 60

for e in range(50):
  print(f"==============Epoch{e}====================")
  model.train()  # Set the model to training mode
  for i in range(0, len(train_data), batch_size):
    model.zero_grad()
    data = train_data[i:i + batch_size]
    label = train_labels[i:i + batch_size]

    data = np.expand_dims(data, axis=0)  # 1x60x294
    au = torch.from_numpy(data[:, :, :35]).float()
    mfccs = torch.from_numpy(data[:, :, 35:]).float()
    y = torch.from_numpy(label).float()

    au = au.cuda()
    mfccs = mfccs.cuda()

    y = y.cuda()

    lengths = torch.LongTensor([au.shape[0]] * au.size(1))  # [1,1,1 ...1]

    fused_features = model(au, mfccs, lengths)
    loss = criterion(fused_features, y)
    loss.backward()
    optimizer.step()

  model.eval()
  with torch.no_grad():
    train_loss, train_acc = eval(train_data, train_labels, mode ="train")
    val_loss, val_acc = eval(train_data, train_labels, mode = "val")
    print("train_loss : {:.3f} train_acc: {:.2f}%".format(train_loss, 100*train_acc))
    print("val_loss : {:.3f} val_acc: {:.2f}%".format(val_loss, 100*val_acc))
  model.train()
# Out:
# ==============Epoch0====================
# train_loss : 2.017 train_acc: 29.31%
# val_loss : 2.017 val_acc: 29.31%
# ==============Epoch1====================
# train_loss : 1.970 train_acc: 29.90%
# val_loss : 1.970 val_acc: 29.90%
# ==============Epoch2====================
# train_loss : 1.888 train_acc: 42.35%
# val_loss : 1.888 val_acc: 42.35%
# ==============Epoch3====================
# train_loss : 1.759 train_acc: 48.33%
# val_loss : 1.759 val_acc: 48.33%
# ==============Epoch4====================
# train_loss : 1.614 train_acc: 50.29%
# val_loss : 1.614 val_acc: 50.29%
# ==============Epoch5====================
# train_loss : 1.467 train_acc: 55.49%
# val_loss : 1.467 val_acc: 55.49%
# ==============Epoch6====================
# train_loss : 1.351 train_acc: 55.39%
# val_loss : 1.351 val_acc: 55.39%
# ==============Epoch7====================
# train_loss : 1.256 train_acc: 57.94%
# val_loss : 1.256 val_acc: 57.94%
# ==============Epoch8====================
# train_loss : 1.179 train_acc: 59.71%
# val_loss : 1.179 val_acc: 59.71%
# ==============Epoch9====================
# train_loss : 1.110 train_acc: 60.88%
# val_loss : 1.110 val_acc: 60.88%
# ==============Epoch10====================
# train_loss : 1.058 train_acc: 61.86%
# val_loss : 1.058 val_acc: 61.86%
# ==============Epoch11====================
# train_loss : 1.008 train_acc: 65.00%
# val_loss : 1.008 val_acc: 65.00%
# ==============Epoch12====================
# train_loss : 0.976 train_acc: 64.31%
# val_loss : 0.976 val_acc: 64.31%
# ==============Epoch13====================
# train_loss : 0.939 train_acc: 66.96%
# val_loss : 0.939 val_acc: 66.96%
# ==============Epoch14====================
# train_loss : 0.914 train_acc: 68.14%
# val_loss : 0.914 val_acc: 68.14%
# ==============Epoch15====================
# train_loss : 0.891 train_acc: 67.65%
# val_loss : 0.891 val_acc: 67.65%
# ==============Epoch16====================
# train_loss : 0.872 train_acc: 67.65%
# val_loss : 0.872 val_acc: 67.65%
# ==============Epoch17====================
# train_loss : 0.856 train_acc: 68.92%
# val_loss : 0.856 val_acc: 68.92%
# ==============Epoch18====================
# train_loss : 0.816 train_acc: 71.18%
# val_loss : 0.816 val_acc: 71.18%
# ==============Epoch19====================
# train_loss : 0.811 train_acc: 70.20%
# val_loss : 0.811 val_acc: 70.20%
# ==============Epoch20====================
# train_loss : 0.790 train_acc: 71.57%
# val_loss : 0.790 val_acc: 71.57%
# ==============Epoch21====================
# train_loss : 0.768 train_acc: 71.57%
# val_loss : 0.768 val_acc: 71.57%
# ==============Epoch22====================
# train_loss : 0.753 train_acc: 72.55%
# val_loss : 0.753 val_acc: 72.55%
# ==============Epoch23====================
# train_loss : 0.743 train_acc: 72.16%
# val_loss : 0.743 val_acc: 72.16%
# ==============Epoch24====================
# train_loss : 0.720 train_acc: 74.80%
# val_loss : 0.720 val_acc: 74.80%
# ==============Epoch25====================
# train_loss : 0.708 train_acc: 73.43%
# val_loss : 0.708 val_acc: 73.43%
# ==============Epoch26====================
# train_loss : 0.703 train_acc: 74.80%
# val_loss : 0.703 val_acc: 74.80%
# ==============Epoch27====================
# train_loss : 0.680 train_acc: 75.29%
# val_loss : 0.680 val_acc: 75.29%
# ==============Epoch28====================
# train_loss : 0.668 train_acc: 76.18%
# val_loss : 0.668 val_acc: 76.18%
# ==============Epoch29====================
# train_loss : 0.656 train_acc: 76.57%
# val_loss : 0.656 val_acc: 76.57%
# ==============Epoch30====================
# train_loss : 0.644 train_acc: 76.96%
# val_loss : 0.644 val_acc: 76.96%
# ==============Epoch31====================
# train_loss : 0.628 train_acc: 77.16%
# val_loss : 0.628 val_acc: 77.16%
# ==============Epoch32====================
# train_loss : 0.612 train_acc: 77.84%
# val_loss : 0.612 val_acc: 77.84%
# ==============Epoch33====================
# train_loss : 0.624 train_acc: 78.14%
# val_loss : 0.624 val_acc: 78.14%
# ==============Epoch34====================
# train_loss : 0.603 train_acc: 78.24%
# val_loss : 0.603 val_acc: 78.24%
# ==============Epoch35====================
# train_loss : 0.587 train_acc: 79.22%
# val_loss : 0.587 val_acc: 79.22%
# ==============Epoch36====================
# train_loss : 0.571 train_acc: 79.61%
# val_loss : 0.571 val_acc: 79.61%
# ==============Epoch37====================
# train_loss : 0.562 train_acc: 79.90%
# val_loss : 0.562 val_acc: 79.90%
# ==============Epoch38====================
# train_loss : 0.556 train_acc: 80.29%
# val_loss : 0.556 val_acc: 80.29%
# ==============Epoch39====================
# train_loss : 0.543 train_acc: 80.10%
# val_loss : 0.543 val_acc: 80.10%
# ==============Epoch40====================
# train_loss : 0.537 train_acc: 81.18%
# val_loss : 0.537 val_acc: 81.18%
# ==============Epoch41====================
# train_loss : 0.522 train_acc: 80.88%
# val_loss : 0.522 val_acc: 80.88%
# ==============Epoch42====================
# train_loss : 0.518 train_acc: 81.47%
# val_loss : 0.518 val_acc: 81.47%
# ==============Epoch43====================
# train_loss : 0.504 train_acc: 81.96%
# val_loss : 0.504 val_acc: 81.96%
# ==============Epoch44====================
# train_loss : 0.501 train_acc: 81.86%
# val_loss : 0.501 val_acc: 81.86%
# ==============Epoch45====================
# train_loss : 0.501 train_acc: 82.45%
# val_loss : 0.501 val_acc: 82.45%
# ==============Epoch46====================
# train_loss : 0.485 train_acc: 82.65%
# val_loss : 0.485 val_acc: 82.65%
# ==============Epoch47====================
# train_loss : 0.479 train_acc: 82.84%
# val_loss : 0.479 val_acc: 82.84%
# ==============Epoch48====================
# train_loss : 0.474 train_acc: 83.24%
# val_loss : 0.474 val_acc: 83.24%
# ==============Epoch49====================
# train_loss : 0.463 train_acc: 83.92%
# val_loss : 0.463 val_acc: 83.92%
